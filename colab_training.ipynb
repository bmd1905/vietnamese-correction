# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/bmd1905/Vietnamese-Corrector.git
# Out:
# Cloning into 'Vietnamese-Corrector'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 67 (delta 21), reused 30 (delta 12), pack-reused 26
# Unpacking objects: 100% (67/67), 57.14 MiB | 7.55 MiB/s, done.
# Updating files: 100% (20/20), done.

# %%
cd /content/Vietnamese-Corrector
# Out:
# /content/Vietnamese-Corrector

# %%
# !pip install -q -r requirements.txt unidecode
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 18.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 110.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.2/826.2 KB 67.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 KB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 42.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.2/517.2 KB 50.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 27.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.2/357.2 KB 36.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 KB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 96.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 KB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.7/139.7 KB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.0/379.0 KB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 102.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 20.6 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done

# %% [markdown]
# # Create dataset

# %%
# !python generate_dataset.py
# Out:
# 2023-02-16 12:33:46.903202: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-16 12:33:48.152420: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-16 12:33:48.152513: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-16 12:33:48.152530: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Downloading (…)lve/main/config.json: 100% 1.72k/1.72k [00:00<00:00, 258kB/s]
# Downloading (…)olve/main/vocab.json: 100% 899k/899k [00:01<00:00, 807kB/s]
# Downloading (…)olve/main/merges.txt: 100% 456k/456k [00:01<00:00, 415kB/s]
# Downloading (…)/main/tokenizer.json: 100% 1.36M/1.36M [00:01<00:00, 1.02MB/s]
# 100% 479568/479568 [01:32<00:00, 5197.69it/s]

# %% [markdown]
# ## Copy files into Drive

# %%
# !cp /content/Vietnamese-Corrector/vi.csv /content/drive/MyDrive

# %%
# !cp /content/Vietnamese-Corrector/vi.test.csv /content/drive/MyDrive

# %%
# !cp /content/Vietnamese-Corrector/vi.train.csv /content/drive/MyDrive

# %% [markdown]
# # Training

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !python /content/Vietnamese-Corrector/run_summarization.py \
    --model_name_or_path facebook/bart-base \
    --do_train \
    --do_eval \
    --evaluation_strategy="steps" \
    --eval_steps=500 \
    --train_file vi.train.csv \
    --validation_file vi.test.csv \
    --output_dir ./models/my-bart-base-en-mix/ \
    --overwrite_output_dir \
    --per_device_train_batch_size=4 \
    --per_device_eval_batch_size=4 \
    --gradient_accumulation_steps=4 \
    --learning_rate="4e-4" \
    --num_train_epochs=1 \
    --predict_with_generate \
	--logging_steps="10" \
    --save_total_limit="2" \
    --max_target_length=1024 \
    --max_source_length=1024 \
    --fp16
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#  29% 144/500 [00:41<01:30,  3.93it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:07,497 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  29% 145/500 [00:41<01:35,  3.73it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:07,798 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  29% 146/500 [00:42<01:33,  3.78it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:08,054 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  29% 147/500 [00:42<01:35,  3.72it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:08,334 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  30% 148/500 [00:42<01:32,  3.82it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:08,580 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  30% 149/500 [00:42<01:30,  3.87it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:08,829 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  30% 150/500 [00:43<01:31,  3.85it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:09,093 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  30% 151/500 [00:43<01:31,  3.83it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:09,356 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  30% 152/500 [00:43<01:34,  3.69it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:09,652 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  31% 153/500 [00:43<01:45,  3.28it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:10,036 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  31% 154/500 [00:44<01:52,  3.09it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:10,405 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  31% 155/500 [00:44<01:53,  3.04it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:10,744 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  31% 156/500 [00:45<01:54,  3.00it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:11,089 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  31% 157/500 [00:45<01:58,  2.91it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:11,459 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  32% 158/500 [00:45<01:59,  2.86it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:11,821 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  32% 159/500 [00:46<02:01,  2.81it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:12,190 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  32% 160/500 [00:46<02:01,  2.79it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:12,556 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  32% 161/500 [00:46<02:00,  2.80it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:12,907 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  32% 162/500 [00:47<01:57,  2.87it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:13,236 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  33% 163/500 [00:47<01:58,  2.84it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:13,599 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  33% 164/500 [00:47<01:59,  2.80it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:13,965 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  33% 165/500 [00:48<02:04,  2.68it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:14,377 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  33% 166/500 [00:48<02:10,  2.57it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:14,805 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  33% 167/500 [00:49<02:11,  2.52it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:15,217 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  34% 168/500 [00:49<02:16,  2.44it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:15,661 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  34% 169/500 [00:50<02:15,  2.44it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:16,071 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  34% 170/500 [00:50<02:05,  2.63it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:16,382 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  34% 171/500 [00:50<01:59,  2.76it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:16,701 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  34% 172/500 [00:50<01:48,  3.01it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:16,961 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  35% 173/500 [00:51<01:39,  3.29it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:17,200 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  35% 174/500 [00:51<01:37,  3.33it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:17,493 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  35% 175/500 [00:51<01:35,  3.39it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:17,776 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  35% 176/500 [00:51<01:32,  3.52it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:18,035 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  35% 177/500 [00:52<01:29,  3.60it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:18,298 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  36% 178/500 [00:52<01:27,  3.68it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:18,555 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  36% 179/500 [00:52<01:26,  3.72it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:18,819 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  36% 180/500 [00:53<01:26,  3.68it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:19,095 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  36% 181/500 [00:53<01:26,  3.69it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:19,365 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  36% 182/500 [00:53<01:24,  3.75it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:19,623 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  37% 183/500 [00:53<01:24,  3.74it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:19,890 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  37% 184/500 [00:54<01:24,  3.75it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:20,154 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  37% 185/500 [00:54<01:22,  3.82it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:20,405 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  37% 186/500 [00:54<01:25,  3.66it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:20,705 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  37% 187/500 [00:54<01:25,  3.65it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:20,980 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  38% 188/500 [00:55<01:28,  3.53it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:21,287 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  38% 189/500 [00:55<01:27,  3.54it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:21,566 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  38% 190/500 [00:55<01:27,  3.56it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:21,846 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  38% 191/500 [00:56<01:25,  3.62it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:22,109 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  38% 192/500 [00:56<01:24,  3.65it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:22,378 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  39% 193/500 [00:56<01:23,  3.69it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:22,644 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  39% 194/500 [00:56<01:21,  3.75it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:22,899 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  39% 195/500 [00:57<01:18,  3.87it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:23,138 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  39% 196/500 [00:57<01:18,  3.89it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:23,393 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  39% 197/500 [00:57<01:18,  3.87it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:23,654 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  40% 198/500 [00:57<01:19,  3.79it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:23,931 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  40% 199/500 [00:58<01:18,  3.84it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:24,184 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  40% 200/500 [00:58<01:18,  3.83it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:24,447 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  40% 201/500 [00:58<01:16,  3.92it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:24,686 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  40% 202/500 [00:58<01:16,  3.91it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:24,944 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  41% 203/500 [00:59<01:15,  3.94it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:25,194 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  41% 204/500 [00:59<01:15,  3.90it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:25,455 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  41% 205/500 [00:59<01:18,  3.74it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:25,750 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  41% 206/500 [00:59<01:18,  3.74it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:26,017 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  41% 207/500 [01:00<01:19,  3.66it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:26,304 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  42% 208/500 [01:00<01:27,  3.33it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:26,667 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  42% 209/500 [01:00<01:32,  3.14it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:27,027 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  42% 210/500 [01:01<01:34,  3.06it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:27,374 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  42% 211/500 [01:01<01:36,  2.99it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:27,729 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  42% 212/500 [01:02<01:46,  2.70it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:28,182 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  43% 213/500 [01:02<01:42,  2.80it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:28,510 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  43% 214/500 [01:02<01:42,  2.78it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:28,876 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  43% 215/500 [01:03<01:40,  2.83it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:29,213 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  43% 216/500 [01:03<01:39,  2.87it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:29,553 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  43% 217/500 [01:03<01:41,  2.78it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:29,939 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  44% 218/500 [01:04<01:47,  2.62it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:30,370 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  44% 219/500 [01:04<01:51,  2.51it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:30,807 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  44% 220/500 [01:05<01:54,  2.44it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:31,245 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  44% 221/500 [01:05<01:52,  2.48it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:31,631 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  44% 222/500 [01:06<01:53,  2.45it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:32,050 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  45% 223/500 [01:06<01:51,  2.47it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:32,446 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  45% 224/500 [01:06<01:47,  2.57it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:32,798 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  45% 225/500 [01:07<01:36,  2.86it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:33,057 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  45% 226/500 [01:07<01:28,  3.11it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:33,313 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  45% 227/500 [01:07<01:22,  3.33it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:33,563 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  46% 228/500 [01:07<01:21,  3.32it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:33,866 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  46% 229/500 [01:08<01:19,  3.41it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:34,142 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  46% 230/500 [01:08<01:19,  3.41it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:34,433 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  46% 231/500 [01:08<01:18,  3.44it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:34,718 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  46% 232/500 [01:08<01:18,  3.40it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:35,020 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  47% 233/500 [01:09<01:17,  3.46it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:35,300 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  47% 234/500 [01:09<01:13,  3.60it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:35,548 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  47% 235/500 [01:09<01:11,  3.70it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:35,801 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  47% 236/500 [01:10<01:09,  3.81it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:36,047 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  47% 237/500 [01:10<01:08,  3.84it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:36,302 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  48% 238/500 [01:10<01:07,  3.90it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:36,550 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  48% 239/500 [01:10<01:06,  3.92it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:36,802 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  48% 240/500 [01:11<01:05,  3.95it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:37,050 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  48% 241/500 [01:11<01:08,  3.78it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:37,342 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  48% 242/500 [01:11<01:08,  3.76it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:37,611 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  49% 243/500 [01:11<01:07,  3.83it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:37,859 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  49% 244/500 [01:12<01:05,  3.92it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:38,101 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  49% 245/500 [01:12<01:04,  3.93it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:38,353 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  49% 246/500 [01:12<01:04,  3.94it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:38,607 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  49% 247/500 [01:12<01:03,  3.99it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:38,850 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  50% 248/500 [01:13<01:03,  3.99it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:39,101 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  50% 249/500 [01:13<01:03,  3.94it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:39,363 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  50% 250/500 [01:13<01:03,  3.95it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:39,614 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  50% 251/500 [01:13<01:02,  3.97it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:39,862 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  50% 252/500 [01:14<01:03,  3.91it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:40,128 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  51% 253/500 [01:14<01:03,  3.90it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:40,386 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  51% 254/500 [01:14<01:02,  3.95it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:40,632 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  51% 255/500 [01:14<01:02,  3.91it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:40,894 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  51% 256/500 [01:15<01:01,  3.96it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:41,138 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  51% 257/500 [01:15<01:01,  3.97it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:41,389 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  52% 258/500 [01:15<01:01,  3.93it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:41,650 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  52% 259/500 [01:15<01:00,  3.97it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:41,897 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  52% 260/500 [01:16<00:59,  4.02it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:42,138 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  52% 261/500 [01:16<00:59,  4.01it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:42,388 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  52% 262/500 [01:16<00:59,  4.02it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:42,635 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  53% 263/500 [01:16<01:08,  3.46it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:43,019 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  53% 264/500 [01:17<01:13,  3.20it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:43,389 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  53% 265/500 [01:17<01:19,  2.97it/s][INFO|configuration_utils.py:543] 2023-02-16 15:51:43,780 >> Generate config GenerationConfig {
# ...
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  93% 464/500 [02:16<00:09,  3.95it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:42,525 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  93% 465/500 [02:16<00:09,  3.87it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:42,795 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  93% 466/500 [02:16<00:08,  3.94it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:43,039 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  93% 467/500 [02:17<00:08,  3.90it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:43,302 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  94% 468/500 [02:17<00:08,  3.90it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:43,558 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  94% 469/500 [02:17<00:07,  3.92it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:43,809 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  94% 470/500 [02:18<00:08,  3.75it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:44,106 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  94% 471/500 [02:18<00:07,  3.66it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:44,392 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  94% 472/500 [02:18<00:07,  3.64it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:44,671 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  95% 473/500 [02:18<00:07,  3.76it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:44,914 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  95% 474/500 [02:19<00:06,  3.80it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:45,172 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  95% 475/500 [02:19<00:06,  3.84it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:45,428 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  95% 476/500 [02:19<00:06,  3.89it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:45,676 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  95% 477/500 [02:19<00:05,  3.94it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:45,923 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  96% 478/500 [02:20<00:05,  3.87it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:46,192 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  96% 479/500 [02:20<00:05,  3.91it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:46,442 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  96% 480/500 [02:20<00:05,  3.98it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:46,682 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  96% 481/500 [02:20<00:04,  4.00it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:46,930 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  96% 482/500 [02:21<00:04,  3.89it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:47,204 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  97% 483/500 [02:21<00:04,  3.83it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:47,476 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  97% 484/500 [02:21<00:04,  3.86it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:47,729 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  97% 485/500 [02:22<00:04,  3.57it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:48,060 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  97% 486/500 [02:22<00:04,  3.21it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:48,445 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  97% 487/500 [02:22<00:04,  3.03it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:48,817 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  98% 488/500 [02:23<00:04,  2.97it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:49,169 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  98% 489/500 [02:23<00:03,  2.90it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:49,532 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  98% 490/500 [02:23<00:03,  2.83it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:49,907 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  98% 491/500 [02:24<00:03,  2.83it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:50,260 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  98% 492/500 [02:24<00:02,  2.79it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:50,632 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  99% 493/500 [02:24<00:02,  2.70it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:51,030 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  99% 494/500 [02:25<00:02,  2.72it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:51,391 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  99% 495/500 [02:25<00:01,  2.71it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:51,764 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  99% 496/500 [02:26<00:01,  2.56it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:52,202 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
#  99% 497/500 [02:26<00:01,  2.54it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:52,606 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
# 100% 498/500 [02:26<00:00,  2.48it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:53,030 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
# 100% 499/500 [02:27<00:00,  2.40it/s][INFO|configuration_utils.py:543] 2023-02-16 15:52:53,481 >> Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
#
# 100% 500/500 [02:27<00:00,  2.39it/s]
# {'eval_loss': 0.1361830234527588, 'eval_cer': 0.810591790689491, 'eval_runtime': 148.7569, 'eval_samples_per_second': 13.445, 'eval_steps_per_second': 3.361, 'epoch': 0.49}
#
#  49% 14500/29848 [3:13:38<2:16:47,  1.87it/s]
#                                      [INFO|trainer.py:2709] 2023-02-16 15:52:54,405 >> Saving model checkpoint to ./models/my-bart-base-en-mix/checkpoint-14500
# [INFO|configuration_utils.py:453] 2023-02-16 15:52:54,410 >> Configuration saved in ./models/my-bart-base-en-mix/checkpoint-14500/config.json
# [INFO|configuration_utils.py:336] 2023-02-16 15:52:54,416 >> Configuration saved in ./models/my-bart-base-en-mix/checkpoint-14500/generation_config.json
# [INFO|modeling_utils.py:1704] 2023-02-16 15:52:56,277 >> Model weights saved in ./models/my-bart-base-en-mix/checkpoint-14500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2160] 2023-02-16 15:52:56,387 >> tokenizer config file saved in ./models/my-bart-base-en-mix/checkpoint-14500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2167] 2023-02-16 15:52:56,393 >> Special tokens file saved in ./models/my-bart-base-en-mix/checkpoint-14500/special_tokens_map.json
# [INFO|trainer.py:2787] 2023-02-16 15:53:00,919 >> Deleting older checkpoint [models/my-bart-base-en-mix/checkpoint-13500] due to args.save_total_limit
# {'loss': 0.1324, 'learning_rate': 0.00020562851782363978, 'epoch': 0.49}
#  49% 14515/29848 [3:13:52<3:37:08,  1.18it/s]

# %% [markdown]
# # Inference

# %%
from transformers import pipeline

fix_spelling = pipeline("text2text-generation", model="/content/Vietnamese-Corrector/models/my-bart-base-en-mix")

# %%
print(fix_spelling("Tôi , đang học AI ở trun tam AI vietnam . ", max_length=2048))
print(fix_spelling("Nhưng sức huỷ divt của cơn bão mitch vẫn chưa thấm vào đâu lsovớithảm hoạ tại Bangladesh ăm 1970", max_length=2048))
print(fix_spelling("Lần này anh Phươngqyết xếp hàng mua bằng được 1 chiếc", max_length=2048))
print(fix_spelling("một số chuyen gia tài chính ngâSn hànG của Việt Nam cũng chung quan điểmnày", max_length=2048))
# Out:
# [{'generated_text': 'Tôi , đang học AI ở trun tam AI vietnam . .'}]
# [{'generated_text': 'Nhưng sức huỷ divt của cơn bão một vẫn chưa thấm vào đâu lo với thể hoạ tỺ�i Bangladesh ăm 1970.'}]
# [{'generated_text': 'Lần này, anh Phương Quyết xáp hàng mua, bằng được 1 chiệc.'}]
# [{'generated_text': 'Một số chuyền gia tài chính ngân hàng của Việt Nam cũng chung quan điểm này.'}]

# %% [markdown]
# # Customize Creaet Dataset

# %%
from lib2to3.pgen2.tokenize import tokenize
import random 
from string import ascii_letters, punctuation, digits
import re
import os
from transformers import AutoTokenizer
from tqdm import tqdm
import sys

def tokenizer_check_if_text_too_long(text, tokenizer, max_length):
    data = tokenizer.batch_encode_plus([text],max_length=max_length,truncation=True,return_overflowing_tokens=True )    
    if len(data["input_ids"]) > 1:
        return True
    else:
        return False#, len(data["input_ids"][0])

def delete_characters(text, char_delete_percentage=0.005):
    modifyed_line = []   
    for char in text:
        if random.random() > char_delete_percentage or char in digits:
            modifyed_line.append(char)
    return "".join(modifyed_line)

def insert_characters(text, augmentation_probability=0.01):
    modifyed_line = []   
    for char in text:
        if random.random() <= augmentation_probability and char not in digits:            
            modifyed_line.append(random.choice(ascii_letters))
        modifyed_line.append(char)
    return "".join(modifyed_line)

def replace_characters(text, augmentation_probability=0.01):
    modifyed_line = []   
    for char in text:
        if random.random() <= augmentation_probability and char not in digits:            
            modifyed_line.append(random.choice(ascii_letters))
        else:
            modifyed_line.append(char)
    return "".join(modifyed_line)

def swap_characters_case(text, augmentation_probability=0.01):
    modifyed_line = []   
    for char in text:
        if random.random() <= augmentation_probability:            
            char = char.swapcase()
        modifyed_line.append(char)
    return "".join(modifyed_line)

def lower_case_words(text, augmentation_probability=0.05):
    modifyed_line = []   
    for word in text.split():
        if word[0].islower() == False and random.random() <= augmentation_probability:            
            word = word.lower()
        modifyed_line.append(word)
    return " ".join(modifyed_line)


clean_chars = re.compile(r'[^A-Za-zöäüÖÄÜß,.!?’\'$%€0-9\(\)\- ]', re.MULTILINE)
def cleanup(text):    
    text = clean_chars.sub('', text)
    #print("bug: somehow all numbers are removed - this is might be due to this regex")
    #exit()
    #text = text.replace("\n", "")
    #text = text.replace('"','\\"')
    return text

clean_punctuation = re.compile(r"(?<!\d)[.,;:'?!](?!\d)")
def remove_punctuation(text):
    """Remove all punctuation from string, except if it's between digits"""
    return clean_punctuation.sub("", text)

def combine_sentences(text, sentences, augmentation_probability = 1):
    if random.random() < augmentation_probability:
        sentences_to_sample = random.randint(0,10)
        augmentation_sentences = random.sample(sentences,sentences_to_sample)    
        return text + " " + " ".join(augmentation_sentences)
    else:
        return text

def delete_word(text, augmentation_probability = 0.001):        
    if random.random() < augmentation_probability:
        words = text.split()
        if len(words) < 3:
            # do not delete word in short text, as there will be no context to guess the word
            return text
        word_to_remove = random.randint(0,len(words)-1)
        words.pop(word_to_remove)
        return " ".join(words)
    else:
        return text
#=========================================================================
import unidecode
import numpy as np

chars_regrex = '[aàảãáạăằẳẵắặâầẩẫấậAÀẢÃÁẠĂẰẲẴẮẶÂẦẨẪẤẬoòỏõóọôồổỗốộơờởỡớợOÒỎÕÓỌÔỒỔỖỐỘƠỜỞỠỚỢeèẻẽéẹêềểễếệEÈẺẼÉẸÊỀỂỄẾỆuùủũúụưừửữứựUÙỦŨÚỤƯỪỬỮỨỰiìỉĩíịIÌỈĨÍỊyỳỷỹýỵYỲỶỸÝỴnNvVmMCG]'
same_chars = {
    'a': ['á', 'à', 'ả', 'ã', 'ạ', 'ấ', 'ầ', 'ẩ', 'ẫ', 'ậ', 'ắ', 'ằ', 'ẳ', 'ẵ', 'ặ'],
    'A': ['Á','À','Ả','Ã','Ạ','Ấ','Ầ','Ẩ','Ẫ','Ậ','Ắ','Ằ','Ẳ','Ẵ','Ặ'],
    'O': ['Ó','Ò','Ỏ','Õ','Ọ','Ô','Ố','Ồ','Ổ','Ỗ','Ộ','Ơ','Ớ','Ờ','Ở','Ỡ','Ợ','Q'],
    'o': ['ó', 'ò', 'ỏ', 'õ', 'ọ', 'ô', 'ố', 'ồ', 'ổ', 'ỗ', 'ộ', 'ơ','ớ', 'ờ', 'ở', 'ỡ', 'ợ', 'q'],
    'e': ['é', 'è', 'ẻ', 'ẽ', 'ẹ', 'ế', 'ề', 'ể', 'ễ', 'ệ', 'ê'],
    'E': ['É', 'È', 'Ẻ', 'Ẽ', 'Ẹ', 'Ế', 'Ề', 'Ể', 'Ễ', 'Ệ', 'Ê'],
    'u': ['ú', 'ù', 'ủ', 'ũ', 'ụ', 'ứ', 'ừ', 'ử', 'ữ', 'ự', 'ư'],
    'U': ['Ú', 'Ù', 'Ủ', 'Ũ', 'Ụ', 'Ứ', 'Ừ', 'Ử', 'Ữ', 'Ự', 'Ư'],
    'i': ['í', 'ì', 'ỉ', 'ĩ', 'ị'],
    'I': ['Í', 'Ì', 'Ỉ', 'Ĩ', 'Ị'],
    'y': ['ý', 'ỳ', 'ỷ', 'ỹ', 'ỵ', 'v'],
    'Y': ['Ý', 'Ỳ', 'Ỷ', 'Ỹ', 'Ỵ', 'V'],
    'n': ['m'],
    'N': ['N'],
    'v': ['y'],
    'V': ['Y'],
    'm': ['n'],
    'M': ['N'],
    'C': ['G'],
    'G': ['C']
}
def _char_regrex(text):
    match_chars = re.findall(chars_regrex, text)
    return match_chars
def _random_replace(text, match_chars):
    replace_char = match_chars[np.random.randint(low=0, high=len(match_chars), size=1)[0]]
    insert_chars = same_chars[unidecode.unidecode(replace_char)]
    insert_char = insert_chars[np.random.randint(low=0, high=len(insert_chars), size=1)[0]]
    text = text.replace(replace_char, insert_char, 1)

    return text
def change(text):
    match_chars = _char_regrex(text)
    if len(match_chars) == 0:
        return text

    text = _random_replace(text, match_chars)

    return text
def replace_accent_chars(text, ratio=0.01):
    words = text.split()
    mask = np.random.random(size=len(words)) < ratio

    for i in range(len(words)):
        if mask[i]:
            words[i] = change(words[i])
            break          

    return ' '.join(words)

def remove_random_accent(text, ratio=0.05):
        words = text.split()
        mask = np.random.random(size=len(words)) < ratio
        
        for i in range(len(words)):
            if mask[i]:
                words[i] = unidecode.unidecode(words[i])
                break

        return ' '.join(words)

# Space between words
def remove_random_space(text):
    words = text.split()
    n_words = len(words)
    start = np.random.randint(low=0, high=n_words, size=1)[0]

    if start + 3 < n_words:
        end = np.random.randint(low=start, high=start + 3, size=1)[0]
    else:
        end = np.random.randint(low=start, high=n_words, size=1)[0]

    out = ' '.join(words[:start])  + ' ' + ''.join(words[start:end + 1]) + ' ' + ' '.join(words[end + 1:])

    return out.strip()

# %%
data_file = "/content/Vietnamese-Corrector/data/data50k.vi.txt" #"data/en.wikidump.processed.24m.txt" #
language = "vi"
num_lines = sum(1 for line in open(data_file, 'r'))

with open(data_file, 'r') as file:
    sentences = file.readlines()

tokenizer = AutoTokenizer.from_pretrained("google/mt5-small") # for vi
#xlm-roberta-base
#facebook/bart-base
#, encoding="utf-8"
count = 0
datas = []
with open(language+".csv", "w") as output:        
    with open(data_file,'r') as file:
        for line in tqdm(file, total=num_lines):
            # if count == 0:
            #   count += 1
            #   continue
            #line = cleanup(line)
            if len(line) < 1:
                continue 

            line = line.replace('"', '')
            
            #line = combine_sentences(line,sentences)
            # print()
            # print(len(line), line)              
            if tokenizer_check_if_text_too_long(line,tokenizer,max_length=1024):
                #print(f"skipping line as its too long ({len(line)}):\n"+line)
                continue
            
            if random.random() > 0.02:
                # we will leave 2% of the data untouched, to teach the 
                # model, not to "overact" on the texts
                # my custom
                new_line = remove_random_space(line)
                new_line = remove_random_accent(new_line)
                new_line = replace_accent_chars(new_line)

                # original
                new_line = swap_characters_case(new_line)  
                new_line = delete_word(new_line)                    
                new_line = delete_characters(new_line)
                new_line = insert_characters(new_line)
                new_line = replace_characters(new_line)
                new_line = lower_case_words(new_line)                                           
                new_line = remove_punctuation(new_line)
            else:
                new_line = line          
            # print(len(new_line), new_line)
            # count += 1
            # break
            # if count == 1:
            #     break
            datas.append([new_line.strip(), line.strip()])
            #count += 1
            # if count == 10:
            #   break
            output.write(f'"{new_line.strip()}","{line.strip()}"\n')        
os.system(f"echo \"text,summary\" > {language}.train.csv")
num_lines = sum(1 for line in open(f"{language}.csv",'r'))
os.system(f"head -n {num_lines-2000} {language}.csv >> {language}.train.csv")
os.system(f"echo \"text,summary\" > {language}.test.csv")
os.system(f"tail -n 2000 {language}.csv >> {language}.test.csv")
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/convert_slow_tokenizer.py:446: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 100%|██████████| 49062/49062 [00:26<00:00, 1844.92it/s]
# 0
